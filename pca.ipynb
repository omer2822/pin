# %%
import numpy as np

# %%
A = np.random.rand(2,3)
B = np.array([[1,complex(imag=1)],[1,0]])
B
# Out:
# array([[1.+0.j, 0.+1.j],
#        [1.+0.j, 0.+0.j]])

# %%
np.linalg.svd(A)
# Out:
# SVDResult(U=array([[-0.86777393, -0.49695916],
#        [-0.49695916,  0.86777393]]), S=array([1.55014751, 0.63226589]), Vh=array([[-0.58928668, -0.56670833, -0.57583234],
#        [ 0.7618359 , -0.15248568, -0.62956666],
#        [ 0.26897449, -0.80968499,  0.52159652]]))

# %%
deactivate
